# %%
# To comment, use Ctrl+/ to comment multiple lines of code in Windows/Linux

print("Hello World!!!")
# Out:
# Hello World!!!

# %%
print("Hello world!\nHello world!\nHello world!")
# Out:
# Hello world!
# Hello world!
# Hello world!

# %%
print("Phoenix"+" "+"Arjuna")
# Out:
# Phoenix Arjuna

# %%
# Space between print and (). This is also correct.

print                            ("Hello, World")
# Out:
# Hello, World

# %%
print("Notes from Day 1")
print("The print statement is used to output strings")
print("Strings are strings of characters")
print("String Concatenation is done with the + sign")
print("New lines can be created with a \ and the letter n")
# Out:
# Notes from Day 1
# The print statement is used to output strings
# Strings are strings of characters
# String Concatenation is done with the + sign
# New lines can be created with a \ and the letter n

# %%
# Space between print and ()

print("Notes from Day 1")
print     ("The print statement is used to output strings")
print          ("Strings are strings of characters")
print              ("String Concatenation is done with the + sign")
print                                                                  ("New lines can be created with a \ and the letter n")
# Out:
# Notes from Day 1
# The print statement is used to output strings
# Strings are strings of characters
# String Concatenation is done with the + sign
# New lines can be created with a \ and the letter n

# %%
input("What is your name?")
# Out:
# What is your name? Venkat
# 'Venkat'

# %%
# Space between input and ()

input                            ("What is your name?")
# Out:
# What is your name? Ram
# 'Ram'

# %%
print("Hello " + input("What is your name?"))
# Out:
# What is your name? Venkat
# Hello Venkat

# %%
print("Hello " + input("What is your name?") + "!")
# Out:
# What is your name? Venkat
# Hello Venkat!

# %%
name = input("What is your name?")
print(name)
# Out:
# What is your name? Venkat
# Venkat

# %%
age                                  =                   input("What is your age?")
print(age)
# Out:
# What is your age? 30
# 30

# %%
name = "Jack"
print(name)

name = "Angela"
print(name)
# Out:
# Jack
# Angela

# %%
name = input("What is your name?")
print(len(name))
# Out:
# What is your name? abcdef
# 6

# %%
print(len(input("What is your name?")))
# Out:
# What is your name? Venkat
# 6

# %%
glass1 = "milk"
glass2 = "juice"


glass1 = "juice"
glass2 = "milk"
print(glass1)
print(glass2)
# Out:
# juice
# milk

# %%
user name = "Venkat"
print(user name)
# Out:
#   Cell In[30], line 1
#     user name = "Venkat"
#          ^
# SyntaxError: invalid syntax

# %%
name = 'Venkat'
print(nama)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 name = 'Venkat'
# ----> 2 print(nama)
#
# NameError: name 'nama' is not defined

# %%
# midnight is written as Midnight in print(),hence the error "name 'time_until_Midnight' is not defined"

time_until_midnight = "5"
print("There are " + time_until_Midnight + " hours until midnight")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 time_until_midnight = "5"
# ----> 2 print("There are " + time_until_Midnight + " hours until midnight")
#
# NameError: name 'time_until_Midnight' is not defined

# %%
num_hours = "5"
print("There are " + num_hours + " hours until midnight")
# Out:
# There are 5 hours until midnight

# %%
time_until_midnight = "5"
print("There are " +time_until_midnight+ " hours until midnight")
# Out:
# There are 5 hours until midnight

# %%
# Day1 project 

print("Welcome to the Band Name Generator.")
city = input("Which city did you grow up in?\n")
pet = input("What is the name of a pet?\n")
print("Your band name could be:" +city+" " + pet)
# Out:
# Welcome to the Band Name Generator.
# Which city did you grow up in?
#  NYC
# What is the name of a pet?
#  Luke
# Your band name could be:NYC Luke
